# %%
from presidio_analyzer import AnalyzerEngine
from presidio_anonymizer import AnonymizerEngine
from presidio_anonymizer.entities import OperatorConfig

# %%
def entity_aware_redaction(text):
    """ 
        Implements the Typed Masking stratergy.
        Replace sensitive data with its category
    """
    analyzer = AnalyzerEngine()
    anonymizer = AnonymizerEngine()

    # Detect the PII entities
    results = analyzer.analyze(text = text , entities=['PERSON' , 'PHONE_NUMBER'] , language='en')

    # Replace with entity type
    anonymized_result = anonymizer.anonymize(
        text=text,
        analyzer_results=results,
        operators={
            "PERSON" : OperatorConfig("replace" , {"new_value" : "<PERSON>"}),
            "PHONE_NUMBER" : OperatorConfig("replace" , {"new_value" : "<PHONE_NUMBER>"})
        }
    )

    return anonymized_result.text

# %%
input = "Dr. Paras called 123-456-7890"
output = entity_aware_redaction(input)
print(output)
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Dr. <PERSON> called <PHONE_NUMBER>
